# %%
import pandas as pd
import numpy as np

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
# %%capture
! pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['bore', 'compression-ratio', 'stroke', 'horsepower']].corr()
# Out:
#                        bore  compression-ratio    stroke  horsepower
# bore               1.000000           0.001263 -0.055390    0.566936
# compression-ratio  0.001263           1.000000  0.187923   -0.214514
# stroke            -0.055390           0.187923  1.000000    0.098462
# horsepower         0.566936          -0.214514  0.098462    1.000000

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
# Out:
# (0, 55902.32751082649)

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0, 48273.79550370898)

# %%
df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
df[['peak-rpm', 'price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.regplot(x='peak-rpm', y='price', data=df)
plt.ylim(0,)
# Out:
# (0, 47436.148325769056)

# %% [markdown]
# Weak correlation: Correlation coeff is close to 0
# Positive correlation: CC close to 1
# Negative correlation: CC close to -1
#
# Regression plot with a positive slop to reg line: positive direct correlation between these two variables
# Regression plot with a negative slop to reg line: inverse relation between these two variables
# The data points are very scattered and far from the fitted line, showing lots of variability.

# %%
df[['stroke', 'price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke', y='price', data=df)

# %% [markdown]
# ### Analysing categorical values

# %%
sns.boxplot(x='body-style', y='price', data=df)

# %%
sns.boxplot(x='engine-location', y='price', data=df)

# %%
df.describe(include='all')
# Out:
#          symboling  normalized-losses    make aspiration num-of-doors  \
# count   201.000000          201.00000     201        201          201
# unique         NaN                NaN      22          2            2
# top            NaN                NaN  toyota        std         four
# freq           NaN                NaN      32        165          115
# mean      0.840796          122.00000     NaN        NaN          NaN
# std       1.254802           31.99625     NaN        NaN          NaN
# min      -2.000000           65.00000     NaN        NaN          NaN
# 25%       0.000000          101.00000     NaN        NaN          NaN
# 50%       1.000000          122.00000     NaN        NaN          NaN
# 75%       2.000000          137.00000     NaN        NaN          NaN
# max       3.000000          256.00000     NaN        NaN          NaN
#
#        body-style drive-wheels engine-location  wheel-base      length  ...  \
# ...

# %%
df.describe(include='object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# ### Grouping and Statistical text analysis

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()

# %%
drive_wheels_counts.rename(columns={'drive-wheels': 'value-counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value-counts
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value-counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group = df[['drive-wheels', 'engine-type', 'price']]
group_table = df_group.groupby(['drive-wheels', 'engine-type'], as_index=False).mean()
group_table
# Out:
#    drive-wheels engine-type         price
# 0           4wd         ohc  11375.333333
# 1           4wd        ohcf   9560.400000
# 2           fwd        dohc  18385.000000
# 3           fwd           l   5151.000000
# 4           fwd         ohc   9074.980952
# 5           fwd        ohcf   7813.285714
# 6           fwd        ohcv  13799.000000
# 7           rwd        dohc  18062.700000
# 8           rwd           l  15489.090909
# 9           rwd         ohc  18655.891892
# 10          rwd        ohcf  34528.000000
# 11          rwd        ohcv  28488.200000
# 12          rwd       rotor  13020.000000

# %%
group_pivot = group_table.pivot(index='drive-wheels', columns='engine-type')
group_pivot = group_pivot.fillna(0)
group_pivot
# Out:
#                 price                                                     \
# engine-type      dohc             l           ohc          ohcf     ohcv
# drive-wheels
# 4wd               0.0      0.000000  11375.333333   9560.400000      0.0
# fwd           18385.0   5151.000000   9074.980952   7813.285714  13799.0
# rwd           18062.7  15489.090909  18655.891892  34528.000000  28488.2
#
#
# engine-type     rotor
# drive-wheels
# 4wd               0.0
# fwd               0.0
# rwd           13020.0

# %% [markdown]
# ## P Value
# ### The P-value is the probability value that the correlation between these two variables is statistically significant

# %%
from scipy import stats

# %%
pearson_coeff, p_val = stats.pearsonr(df['wheel-base'], df['price'])

# %%
print('Pearson coefficient is ', pearson_coeff, ' p value ', p_val)
# Out:
# Pearson coefficient is  0.584641822265508  p value  8.076488270733218e-20

# %% [markdown]
# #### PC is close to 0.5 which means the linear relationship is not strong enough, but p value < 0.001 which means the corelation is statistically significant

# %%
p_c, p_v = stats.pearsonr(df['horsepower'], df['price'])
print('Pearson coefficient is ', p_c, ' p value ', p_v)
# Out:
# Pearson coefficient is  0.809574567003656  p value  6.369057428259557e-48

# %% [markdown]
# #### PC is close to 1 which means there is a positive linear relationship; p value < 0.001 which eans the correlation is statistically significant

# %%
p_c1, p_v1 = stats.pearsonr(df['length'], df['price'])
print('Pearson coefficient is ', p_c1, ' p value ', p_v1)
# Out:
# Pearson coefficient is  0.690628380448364  p value  8.016477466158986e-30

# %% [markdown]
# #### PC is 0.6 which means there is a weak linear relationship, but low P value indicate correlation is staitically significant

# %%
p_c2, p_v2 = stats.pearsonr(df['curb-weight'], df['price'])
print('Pearson coefficient is ', p_c2, ' p value ', p_v2)
# Out:
# Pearson coefficient is  0.8344145257702846  p value  2.1895772388936914e-53

# %% [markdown]
# #### PC is close to 1 which indicate a strong linear relationship and very low p value means the correlation is statistically significant
